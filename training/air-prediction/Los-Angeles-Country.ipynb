# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import datetime

# %%
LA_CO_full = pd.concat(map(pd.read_csv, ['gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/CO/2015.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/CO/2016.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/CO/2017.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/CO/2018.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/CO/2019.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/CO/2020.csv'])
, ignore_index=True)

# %%
import datetime
# the data is collected across multiple sites daily
# TODO: Consider the geographical distribution of the sites and their proximity to each other.
# this function calculates the daily average across all sites - Spatial aggregation
def calculate_daily_average(dataset, date_column, pollutant):
  # Ensure the date column is in datetime format
  dataset[date_column] = pd.to_datetime(dataset[date_column])
  dataset[date_column] = dataset[date_column].dt.date
  daily_avg = dataset.groupby(date_column)[pollutant].mean().reset_index()

  return daily_avg

# %%
LA_CO_full = calculate_daily_average(LA_CO_full, 'Date', 'Daily Max 8-hour CO Concentration')

# %%
# Some of the dataset contain missing dates
# this method finds those dates
def find_missing_dates(data, date_column):
  # Ensure the date column is in datetime format
  data[date_column] = pd.to_datetime(data[date_column])
  # Create a full range od dates
  min_date = data[date_column].min()
  max_date = data[date_column].max()
  full_dates = pd.date_range(start=min_date, end=max_date, freq='D')

  # Find missing dates
  missing_dates = full_dates.difference(data[date_column])

  return missing_dates

# %%
missing_dates = find_missing_dates(LA_CO_full, 'Date')

# %%
print(missing_dates)
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq='D')

# %%
LA_NO2_full = pd.concat(map(pd.read_csv, ['gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/NO2/2015.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/NO2/2016.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/NO2/2017.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/NO2/2018.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/NO2/2019.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/NO2/2020.csv'])
, ignore_index=True)

# %%
LA_NO2_full = calculate_daily_average(LA_NO2_full, 'Date', 'Daily Max 1-hour NO2 Concentration')
missing_dates = find_missing_dates(LA_NO2_full, 'Date')
print(missing_dates)
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq='D')

# %%
LA_Ozone_full = pd.concat(map(pd.read_csv, ['gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/Ozone/2015.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/Ozone/2016.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/Ozone/2017.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/Ozone/2018.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/Ozone/2019.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/Ozone/2020.csv'])
, ignore_index=True)

# %%
LA_Ozone_full = calculate_daily_average(LA_Ozone_full, 'Date', 'Daily Max 8-hour Ozone Concentration')
missing_dates = find_missing_dates(LA_Ozone_full, 'Date')
print(missing_dates)
# Out:
# DatetimeIndex(['2015-12-31', '2016-12-31', '2017-12-31', '2018-12-31',
#                '2019-12-31'],
#               dtype='datetime64[ns]', freq=None)

# %%
def process_data(data,  date_column, missing_dates):
  # Convert 'Date' column to datetime if it is not already
  data[date_column] = pd.to_datetime(data[date_column])

  # Set 'Date' as the index
  data.set_index(date_column, inplace=True)

  # Add the missing dates to the DataFrame with NaN values
  data = data.reindex(data.index.union(missing_dates))

  #Reset index to make 'Date' a regular column again
  data.reset_index(inplace=True)

  data.fillna(0, inplace=True)

  return data

# %%
LA_Ozone_full = process_data(LA_Ozone_full, 'Date', missing_dates)

# %%
# manually add 2020-12-31
new_entry = {'index': pd.to_datetime('2020-12-31'), 'Daily Max 8-hour Ozone Concentration': 0.0326668}
LA_Ozone_full.loc[len(LA_Ozone_full)] = new_entry

LA_Ozone_full.reset_index(drop=True, inplace=True)

# %%
LA_PM2_full = pd.concat(map(pd.read_csv, ['gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/PM2.5/2015.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/PM2.5/2016.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/PM2.5/2017.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/PM2.5/2018.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/PM2.5/2019.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/PM2.5/2020.csv'])
, ignore_index=True)

# %%
LA_PM2_full = calculate_daily_average(LA_PM2_full, 'Date', 'Daily Mean PM2.5 Concentration')
missing_dates = find_missing_dates(LA_PM2_full, 'Date')
print(missing_dates)
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq='D')

# %%
LA_PM10_full = pd.concat(map(pd.read_csv, ['gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/PM10/2015.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/PM10/2016.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/PM10/2017.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/PM10/2018.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/PM10/2019.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/PM10/2020.csv'])
, ignore_index=True)

# %%
LA_PM10_full = calculate_daily_average(LA_PM10_full, 'Date', 'Daily Mean PM10 Concentration')
missing_dates = find_missing_dates(LA_PM10_full, 'Date')
print(missing_dates)
# Out:
# DatetimeIndex(['2019-05-22', '2019-05-23'], dtype='datetime64[ns]', freq=None)

# %%
LA_PM10_full = process_data(LA_PM10_full, 'Date', missing_dates)

# %%
LA_SO2_full = pd.concat(map(pd.read_csv, ['gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/SO2/2015.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/SO2/2016.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/SO2/2017.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/SO2/2018.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/SO2/2019.csv',
                                     'gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/Los-Angeles/SO2/2020.csv'])
, ignore_index=True)

# %%
LA_SO2_full = calculate_daily_average(LA_SO2_full, 'Date', 'Daily Max 1-hour SO2 Concentration')
missing_dates = find_missing_dates(LA_SO2_full, 'Date')
print(missing_dates)
# Out:
# DatetimeIndex(['2015-05-13', '2015-06-12'], dtype='datetime64[ns]', freq=None)

# %%
LA_SO2_full = process_data(LA_SO2_full, 'Date', missing_dates)

# %%
LA_CO_full.rename(columns = {'index':'Date'}, inplace = True)
LA_NO2_full.rename(columns = {'index':'Date'}, inplace = True)
LA_Ozone_full.rename(columns = {'index':'Date'}, inplace = True)
LA_PM2_full.rename(columns = {'index':'Date'}, inplace = True)
LA_PM10_full.rename(columns = {'index':'Date'}, inplace = True)
LA_SO2_full.rename(columns = {'index':'Date'}, inplace = True)

# %%
from functools import reduce
combine = reduce(lambda x,y: pd.merge(x,y, on='Date', how='outer'), [LA_CO_full,LA_NO2_full,LA_Ozone_full,LA_PM2_full,LA_PM10_full,LA_SO2_full])

# %%
combine.head()
# Out:
#         Date  Daily Max 8-hour CO Concentration  \
# 0 2015-01-01                           1.078571
# 1 2015-01-02                           0.985714
# 2 2015-01-03                           1.007143
# 3 2015-01-04                           1.100000
# 4 2015-01-05                           0.792308
#
#    Daily Max 1-hour NO2 Concentration  Daily Max 8-hour Ozone Concentration  \
# 0                           31.123077                              0.034615
# 1                           35.963636                              0.031273
# 2                           35.138462                              0.033846
# 3                           35.661538                              0.034583
# 4                           36.153846                              0.028909
#
#    Daily Mean PM2.5 Concentration  Daily Mean PM10 Concentration  \
# 0                       34.075000                           23.0
# 1                       22.925000                           23.0
# 2                       24.214286                           28.5
# 3                       26.350000                           24.5
# 4                        9.087500                           17.5
#
#    Daily Max 1-hour SO2 Concentration
# 0                            1.500000
# 1                            0.600000
# 2                            1.600000
# 3                            1.033333
# 4                            1.800000

# %%
combine.rename(columns = {'Daily Max 8-hour CO Concentration':'CO', 'Daily Max 1-hour NO2 Concentration': 'NO2',
                          'Daily Max 8-hour Ozone Concentration': 'Ozone', 'Daily Mean PM2.5 Concentration': 'PM2.5',
                          'Daily Mean PM10 Concentration': 'PM10', 'Daily Max 1-hour SO2 Concentration': 'SO2' }, inplace = True)

# %%
combine
# Out:
#            Date        CO        NO2     Ozone      PM2.5       PM10       SO2
# 0    2015-01-01  1.078571  31.123077  0.034615  34.075000  23.000000  1.500000
# 1    2015-01-02  0.985714  35.963636  0.031273  22.925000  23.000000  0.600000
# 2    2015-01-03  1.007143  35.138462  0.033846  24.214286  28.500000  1.600000
# 3    2015-01-04  1.100000  35.661538  0.034583  26.350000  24.500000  1.033333
# 4    2015-01-05  0.792308  36.153846  0.028909   9.087500  17.500000  1.800000
# ...         ...       ...        ...       ...        ...        ...       ...
# 2187 2020-12-27  0.561538  21.400000  0.033417  13.030769  19.000000  0.450000
# 2188 2020-12-28  0.325000  21.006667  0.032500   6.030769   7.000000  0.200000
# 2189 2020-12-29  0.615385  31.143750  0.030917   8.904545  11.142857  0.900000
# 2190 2020-12-30  0.723077  35.681250  0.031750  12.823077  13.000000  0.850000
# 2191 2020-12-31  0.881818  32.168750  0.032667  19.484615  13.500000  0.700000
#
# [2192 rows x 7 columns]

# %%
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
pio.templates.default = "plotly_white"

# %%
# descriptive statistics of the data
print(combine.describe())
# Out:
#                 CO          NO2        Ozone        PM2.5         PM10  \
# count  2192.000000  2192.000000  2192.000000  2192.000000  2192.000000
# mean      0.507530    27.569752     0.046000    12.065833    26.040782
# std       0.254766    10.636906     0.013037     5.873577    13.160007
# min       0.150000     4.200000     0.000000     2.488235     0.000000
# 25%       0.300000    19.035664     0.036385     8.545294    17.404762
# 50%       0.435714    26.512500     0.046231    11.107670    25.387500
# 75%       0.671429    35.300000     0.054924    14.304545    33.000000
# max       1.646154    65.642857     0.092643    64.381818   140.000000
#
#                SO2
# count  2192.000000
# mean      1.493355
# std       1.074787
# min       0.000000
# 25%       0.750000
# 50%       1.250000
# 75%       1.966667
# max      13.033333

# %%
# show intensity of each pollutant over time
fig = go.Figure()

for pollutant in ['CO', 'NO2', 'Ozone', 'PM2.5', 'PM10', 'SO2']:
  fig.add_trace(go.Scatter(x=combine['Date'], y=combine[pollutant], mode='lines',
                           name=pollutant))

fig.update_layout(title='Time Series Analysis of Air Pollutants in Los Angeles',
                  xaxis_title='Date', yaxis_title='Concentration (ug/m3)')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ea41f2a3-394b-455d-8820-60e0a3243ceb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea41f2a3-394b-455d-8820-60e0a3243ceb")) {                    Plotly.newPlot(                        "ea41f2a3-394b-455d-8820-60e0a3243ceb",                        [{"mode":"lines","name":"CO","x":["2015-01-01T00:00:00","2015-01-02T00:00:00","2015-01-03T00:00:00","2015-01-04T00:00:00","2015-01-05T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-10T00:00:00","2015-01-11T00:00:00","2015-01-12T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-17T00:00:00","2015-01-18T00:00:00","2015-01-19T00:00:00","2015-01-20T00:00:00","2015-01-21T00:00:00","2015-01-22T00:00:00","2015-01-23T00:00:00","2015-01-24T00:00:00","2015-01-25T00:00:00","2015-01-26T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-29T00:00:00","2015-01-30T00:00:00","2015-01-31T00:00:00","2015-02-01T00:00:00","2015-02-02T00:00:00","2015-02-03T00:00:00","2015-02-04T00:00:00","2015-02-05T00:00:00","2015-02-06T00:00:00","2015-02-07T00:00:00","2015-02-08T00:00:00","2015-02-09T00:00:00","2015-02-10T00:00:00","2015-02-11T00:00:00","2015-02-12T00:00:00","2015-02-13T00:00:00","2015-02-14T00:00:00","2015-02-15T00:00:00","2015-02-16T00:00:00","2015-02-17T00:00:00","2015-02-18T00:00:00","2015-02-19T00:00:00","2015-02-20T00:00:00","2015-02-21T00:00:00","2015-02-22T00:00:00","2015-02-23T00:00:00","2015-02-24T00:00:00","2015-02-25T00:00:00","2015-02-26T00:00:00","2015-02-27T00:00:00","2015-02-28T00:00:00","2015-03-01T00:00:00","2015-03-02T00:00:00","2015-03-03T00:00:00","2015-03-04T00:00:00","2015-03-05T00:00:00","2015-03-06T00:00:00","2015-03-07T00:00:00","2015-03-08T00:00:00","2015-03-09T00:00:00","2015-03-10T00:00:00","2015-03-11T00:00:00","2015-03-12T00:00:00","2015-03-13T00:00:00","2015-03-14T00:00:00","2015-03-15T00:00:00","2015-03-16T00:00:00","2015-03-17T00:00:00","2015-03-18T00:00:00","2015-03-19T00:00:00","2015-03-20T00:00:00","2015-03-21T00:00:00","2015-03-22T00:00:00","2015-03-23T00:00:00","2015-03-24T00:00:00","2015-03-25T00:00:00","2015-03-26T00:00:00","2015-03-27T00:00:00","2015-03-28T00:00:00","2015-03-29T00:00:00","2015-03-30T00:00:00","2015-03-31T00:00:00","2015-04-01T00:00:00","2015-04-02T00:00:00","2015-04-03T00:00:00","2015-04-04T00:00:00","2015-04-05T00:00:00","2015-04-06T00:00:00","2015-04-07T00:00:00","2015-04-08T00:00:00","2015-04-09T00:00:00","2015-04-10T00:00:00","2015-04-11T00:00:00","2015-04-12T00:00:00","2015-04-13T00:00:00","2015-04-14T00:00:00","2015-04-15T00:00:00","2015-04-16T00:00:00","2015-04-17T00:00:00","2015-04-18T00:00:00","2015-04-19T00:00:00","2015-04-20T00:00:00","2015-04-21T00:00:00","2015-04-22T00:00:00","2015-04-23T00:00:00","2015-04-24T00:00:00","2015-04-25T00:00:00","2015-04-26T00:00:00","2015-04-27T00:00:00","2015-04-28T00:00:00","2015-04-29T00:00:00","2015-04-30T00:00:00","2015-05-01T00:00:00","2015-05-02T00:00:00","2015-05-03T00:00:00","2015-05-04T00:00:00","2015-05-05T00:00:00","2015-05-06T00:00:00","2015-05-07T00:00:00","2015-05-08T00:00:00","2015-05-09T00:00:00","2015-05-10T00:00:00","2015-05-11T00:00:00","2015-05-12T00:00:00","2015-05-13T00:00:00","2015-05-14T00:00:00","2015-05-15T00:00:00","2015-05-16T00:00:00","2015-05-17T00:00:00","2015-05-18T00:00:00","2015-05-19T00:00:00","2015-05-20T00:00:00","2015-05-21T00:00:00","2015-05-22T00:00:00","2015-05-23T00:00:00","2015-05-24T00:00:00","2015-05-25T00:00:00","2015-05-26T00:00:00","2015-05-27T00:00:00","2015-05-28T00:00:00","2015-05-29T00:00:00","2015-05-30T00:00:00","2015-05-31T00:00:00","2015-06-01T00:00:00","2015-06-02T00:00:00","2015-06-03T00:00:00","2015-06-04T00: ...

# %%
#Calculate Air Quality Index
aqi_breakpoints = [
    (0, 12.0, 50), (12.1, 35.4, 100), (35.5, 55.4, 150),
    (55.5, 150.4, 200), (150.5, 250.4, 300), (250.5, 350.4, 400),
    (350.5, 500.4, 500)
]

def calculate_aqi(pollutant_name, concentration):
  for low, high, aqi in aqi_breakpoints:
    if low <= concentration <= high:
      return aqi
  return None

def calculate_overall_aqi(row):
  aqi_values = []
  pollutants = ['CO', 'NO2', 'Ozone', 'PM2.5', 'PM10', 'SO2']
  for pollutant in pollutants:
    aqi = calculate_aqi(pollutant, row[pollutant])
    if aqi is not None:
      aqi_values.append(aqi)
  return max(aqi_values)


# Calculate AQI for each row
combine['AQI'] = combine.apply(calculate_overall_aqi, axis=1)

# Define AQI categories
aqi_categories = [
    (0, 50, 'Good'), (51, 100, 'Moderate'), (101, 150, 'Unhealthy for Sensitive Groups'),
    (151, 200, 'Unhealthy'), (201, 300, 'Very Unhealthy'), (301, 500, 'Hazardous')
]

def categorize_aqi(aqi_value):
  for low, high, category in aqi_categories:
    if low <= aqi_value <= high:
      return category
  return None

# %%
#Categorize AQI
combine['AQI Category'] = combine['AQI'].apply(categorize_aqi)
print(combine.head())
# Out:
#         Date        CO        NO2     Ozone      PM2.5  PM10       SO2  AQI  \
# 0 2015-01-01  1.078571  31.123077  0.034615  34.075000  23.0  1.500000  100
# 1 2015-01-02  0.985714  35.963636  0.031273  22.925000  23.0  0.600000  150
# 2 2015-01-03  1.007143  35.138462  0.033846  24.214286  28.5  1.600000  100
# 3 2015-01-04  1.100000  35.661538  0.034583  26.350000  24.5  1.033333  150
# 4 2015-01-05  0.792308  36.153846  0.028909   9.087500  17.5  1.800000  150
#
#                      AQI Category
# 0                        Moderate
# 1  Unhealthy for Sensitive Groups
# 2                        Moderate
# 3  Unhealthy for Sensitive Groups
# 4  Unhealthy for Sensitive Groups

# %%
asthma_data = pd.read_csv('gdrive/MyDrive/ColabNotebooks/air-prediction/air-quality-California/asthma-hospitalization-rates-by-county.csv', encoding="ISO-8859-1")

asthma_data['NUMBER OF HOSPITALIZATIONS'] = asthma_data['NUMBER OF HOSPITALIZATIONS'].str.replace(',', '').astype(float)

print(asthma_data.head())
# Out:
#        COUNTY  YEAR            STRATA STRATA NAME AGE GROUP  \
# 0  California  2015  Total population    All ages  All ages
# 1     Alameda  2015  Total population    All ages  All ages
# 2      Alpine  2015  Total population    All ages  All ages
# 3      Amador  2015  Total population    All ages  All ages
# 4       Butte  2015  Total population    All ages  All ages
#
#    NUMBER OF HOSPITALIZATIONS  AGE-ADJUSTED HOSPITALIZATION RATE COMMENT
# 0                     27262.0                                7.0     NaN
# 1                      1435.0                                9.3     NaN
# 2                         0.0                                0.0     NaN
# 3                        28.0                                7.5     NaN
# 4                       143.0                                6.7     NaN

# %%
combine['COUNTY'] = 'Los Angeles'

# %%
combine['Date'] = pd.to_datetime(combine['Date'])
combine_yearly = combine.groupby(['COUNTY',combine['Date'].dt.year]).mean().reset_index()
combine_yearly.rename(columns = {'Date':'YEAR'}, inplace = True)
merged_data = pd.merge(asthma_data, combine_yearly, how='inner', left_on=['COUNTY', 'YEAR'], right_on=['COUNTY', 'YEAR'])
# Perform correlation analysis
correlation_matrix = merged_data[['NUMBER OF HOSPITALIZATIONS', 'CO', 'NO2', 'Ozone', 'PM2.5', 'SO2', 'AQI']].corr()
# Out:
# <ipython-input-36-28fbee1b0bae>:2: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
merged_data.head(5)
# Out:
#         COUNTY  YEAR            STRATA STRATA NAME   AGE GROUP  \
# 0  Los Angeles  2015  Total population    All ages    All ages
# 1  Los Angeles  2015   Child vs. adult  017 years  017 years
# 2  Los Angeles  2015   Child vs. adult   18+ years   18+ years
# 3  Los Angeles  2015        Age groups   04 years   04 years
# 4  Los Angeles  2015        Age groups  517 years  517 years
#
#    NUMBER OF HOSPITALIZATIONS  AGE-ADJUSTED HOSPITALIZATION RATE COMMENT  \
# 0                      8544.0                                8.5     NaN
# 1                      2639.0                               11.1     NaN
# 2                      5905.0                                7.6     NaN
# 3                      1276.0                               18.7     NaN
# 4                      1363.0                                8.4     NaN
#
#          CO        NO2     Ozone      PM2.5       PM10       SO2    AQI
# 0  0.521568  29.419242  0.046073  12.544851  23.918607  1.659269  120.0
# 1  0.521568  29.419242  0.046073  12.544851  23.918607  1.659269  120.0
# 2  0.521568  29.419242  0.046073  12.544851  23.918607  1.659269  120.0
# 3  0.521568  29.419242  0.046073  12.544851  23.918607  1.659269  120.0
# 4  0.521568  29.419242  0.046073  12.544851  23.918607  1.659269  120.0

# %%
print(correlation_matrix)
# Out:
#                             NUMBER OF HOSPITALIZATIONS        CO       NO2  \
# NUMBER OF HOSPITALIZATIONS                    1.000000  0.216207  0.339108
# CO                                            0.216207  1.000000  0.867739
# NO2                                           0.339108  0.867739  1.000000
# Ozone                                        -0.168462  0.293573 -0.095429
# PM2.5                                        -0.044923  0.429105  0.112738
# SO2                                           0.307693  0.720889  0.840721
# AQI                                           0.116321  0.891082  0.624916
#
#                                Ozone     PM2.5       SO2       AQI
# NUMBER OF HOSPITALIZATIONS -0.168462 -0.044923  0.307693  0.116321
# CO                          0.293573  0.429105  0.720889  0.891082
# NO2                        -0.095429  0.112738  0.840721  0.624916
# Ozone                       1.000000  0.796821 -0.425765  0.301594
# PM2.5                       0.796821  1.000000 -0.171687  0.530335
# SO2                        -0.425765 -0.171687  1.000000  0.630761
# AQI                         0.301594  0.530335  0.630761  1.000000

# %%
# AQI over time
fig = px.bar(combine, x="Date", y="AQI",
             title="AQI of Los Angeles from 2015 - 2020")
fig.update_xaxes(title='Date')
fig.update_yaxes(title="AQI")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8a8b7082-2348-46bb-a91e-7ab27aa65632" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a8b7082-2348-46bb-a91e-7ab27aa65632")) {                    Plotly.newPlot(                        "8a8b7082-2348-46bb-a91e-7ab27aa65632",                        [{"alignmentgroup":"True","hovertemplate":"Date=%{x}\u003cbr\u003eAQI=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2015-01-01T00:00:00","2015-01-02T00:00:00","2015-01-03T00:00:00","2015-01-04T00:00:00","2015-01-05T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-10T00:00:00","2015-01-11T00:00:00","2015-01-12T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-17T00:00:00","2015-01-18T00:00:00","2015-01-19T00:00:00","2015-01-20T00:00:00","2015-01-21T00:00:00","2015-01-22T00:00:00","2015-01-23T00:00:00","2015-01-24T00:00:00","2015-01-25T00:00:00","2015-01-26T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-29T00:00:00","2015-01-30T00:00:00","2015-01-31T00:00:00","2015-02-01T00:00:00","2015-02-02T00:00:00","2015-02-03T00:00:00","2015-02-04T00:00:00","2015-02-05T00:00:00","2015-02-06T00:00:00","2015-02-07T00:00:00","2015-02-08T00:00:00","2015-02-09T00:00:00","2015-02-10T00:00:00","2015-02-11T00:00:00","2015-02-12T00:00:00","2015-02-13T00:00:00","2015-02-14T00:00:00","2015-02-15T00:00:00","2015-02-16T00:00:00","2015-02-17T00:00:00","2015-02-18T00:00:00","2015-02-19T00:00:00","2015-02-20T00:00:00","2015-02-21T00:00:00","2015-02-22T00:00:00","2015-02-23T00:00:00","2015-02-24T00:00:00","2015-02-25T00:00:00","2015-02-26T00:00:00","2015-02-27T00:00:00","2015-02-28T00:00:00","2015-03-01T00:00:00","2015-03-02T00:00:00","2015-03-03T00:00:00","2015-03-04T00:00:00","2015-03-05T00:00:00","2015-03-06T00:00:00","2015-03-07T00:00:00","2015-03-08T00:00:00","2015-03-09T00:00:00","2015-03-10T00:00:00","2015-03-11T00:00:00","2015-03-12T00:00:00","2015-03-13T00:00:00","2015-03-14T00:00:00","2015-03-15T00:00:00","2015-03-16T00:00:00","2015-03-17T00:00:00","2015-03-18T00:00:00","2015-03-19T00:00:00","2015-03-20T00:00:00","2015-03-21T00:00:00","2015-03-22T00:00:00","2015-03-23T00:00:00","2015-03-24T00:00:00","2015-03-25T00:00:00","2015-03-26T00:00:00","2015-03-27T00:00:00","2015-03-28T00:00:00","2015-03-29T00:00:00","2015-03-30T00:00:00","2015-03-31T00:00:00","2015-04-01T00:00:00","2015-04-02T00:00:00","2015-04-03T00:00:00","2015-04-04T00:00:00","2015-04-05T00:00:00","2015-04-06T00:00:00","2015-04-07T00:00:00","2015-04-08T00:00:00","2015-04-09T00:00:00","2015-04-10T00:00:00","2015-04-11T00:00:00","2015-04-12T00:00:00","2015-04-13T00:00:00","2015-04-14T00:00:00","2015-04-15T00:00:00","2015-04-16T00:00:00","2015-04-17T00:00:00","2015-04-18T00:00:00","2015-04-19T00:00:00","2015-04-20T00:00:00","2015-04-21T00:00:00","2015-04-22T00:00:00","2015-04-23T00:00:00","2015-04-24T00:00:00","2015-04-25T00:00:00","2015-04-26T00:00:00","2015-04-27T00:00:00","2015-04-28T00:00:00","2015-04-29T00:00:00","2015-04-30T00:00:00","2015-05-01T00:00:00","2015-05-02T00:00:00","2015-05-03T00:00:00","2015-05-04T00:00:00","2015-05-05T00:00:00","2015-05-06T00:00:00","2015-05-07T00:00:00","2015-05-08T00:00:00","2015-05-09T00:00:00","2015-05-10T00:00:00","2015-05-11T00:00:00","2015-05-12T00:00:00","2015-05-13T00:00:00","2015-05-14T00:00:00","2015-05-15T00:00:00","2015-05-16T00:00:00","2015-05-17T00:00:00","2015-05-18T00:00:00","2015-05-19T00:00:00","2015-05-20T00:00:00","2015-05-21T00:00:00","2015-05-22T00:00:00","2015-05-23T00:00:00","2015-05-24T00: ...

# %%
# AQI Category distribution
fig = px.histogram(combine, x="Date",
                   color="AQI Category",
                   title="AQI Category Distribution Over Time")
fig.update_xaxes(title="Date")
fig.update_yaxes(title="Count")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9d8d4121-1394-4733-8da6-ab68d94c66b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d8d4121-1394-4733-8da6-ab68d94c66b6")) {                    Plotly.newPlot(                        "9d8d4121-1394-4733-8da6-ab68d94c66b6",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"AQI Category=Moderate\u003cbr\u003eDate=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Moderate","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Moderate","offsetgroup":"Moderate","orientation":"v","showlegend":true,"x":["2015-01-01T00:00:00","2015-01-03T00:00:00","2015-01-11T00:00:00","2015-01-12T00:00:00","2015-01-13T00:00:00","2015-01-26T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-30T00:00:00","2015-01-31T00:00:00","2015-02-01T00:00:00","2015-02-08T00:00:00","2015-02-09T00:00:00","2015-02-16T00:00:00","2015-02-17T00:00:00","2015-02-21T00:00:00","2015-02-22T00:00:00","2015-02-23T00:00:00","2015-02-24T00:00:00","2015-02-27T00:00:00","2015-02-28T00:00:00","2015-03-01T00:00:00","2015-03-02T00:00:00","2015-03-03T00:00:00","2015-03-08T00:00:00","2015-03-15T00:00:00","2015-03-18T00:00:00","2015-03-19T00:00:00","2015-03-20T00:00:00","2015-03-21T00:00:00","2015-03-22T00:00:00","2015-03-23T00:00:00","2015-03-24T00:00:00","2015-03-28T00:00:00","2015-03-29T00:00:00","2015-03-30T00:00:00","2015-04-01T00:00:00","2015-04-02T00:00:00","2015-04-05T00:00:00","2015-04-06T00:00:00","2015-04-07T00:00:00","2015-04-08T00:00:00","2015-04-09T00:00:00","2015-04-10T00:00:00","2015-04-11T00:00:00","2015-04-12T00:00:00","2015-04-13T00:00:00","2015-04-18T00:00:00","2015-04-20T00:00:00","2015-04-21T00:00:00","2015-04-22T00:00:00","2015-04-23T00:00:00","2015-04-24T00:00:00","2015-04-25T00:00:00","2015-04-26T00:00:00","2015-05-01T00:00:00","2015-05-02T00:00:00","2015-05-03T00:00:00","2015-05-04T00:00:00","2015-05-05T00:00:00","2015-05-06T00:00:00","2015-05-07T00:00:00","2015-05-08T00:00:00","2015-05-09T00:00:00","2015-05-10T00:00:00","2015-05-11T00:00:00","2015-05-12T00:00:00","2015-05-13T00:00:00","2015-05-14T00:00:00","2015-05-15T00:00:00","2015-05-16T00:00:00","2015-05-17T00:00:00","2015-05-18T00:00:00","2015-05-19T00:00:00","2015-05-20T00:00:00","2015-05-21T00:00:00","2015-05-22T00:00:00","2015-05-23T00:00:00","2015-05-24T00:00:00","2015-05-25T00:00:00","2015-05-26T00:00:00","2015-05-27T00:00:00","2015-05-28T00:00:00","2015-05-29T00:00:00","2015-05-30T00:00:00","2015-05-31T00:00:00","2015-06-01T00:00:00","2015-06-02T00:00:00","2015-06-03T00:00:00","2015-06-04T00:00:00","2015-06-05T00:00:00","2015-06-06T00:00:00","2015-06-07T00:00:00","2015-06-08T00:00:00","2015-06-09T00:00:00","2015-06-10T00:00:00","2015-06-11T00:00:00","2015-06-12T00:00:00","2015-06-13T00:00:00","2015-06-14T00:00:00","2015-06-15T00:00:00","2015-06-17T00:00:00","2015-06-18T00:00:00","2015-06-20T00:00:00","2015-06-21T00:00:00","2015-06-22T00:00:00","2015-06-26T00:00:00","2015-06-27T00:00:00","2015-06-28T00:00:00","2015-07-01T00:00:00","2015-07-02T00:00:00","2015-07-03T00:00:00","2015-07-04T00:00:00","2015-07-05T00:00:00","2015-07-06T00:00:00","2015-07-07T00:00:00","2015-07-08T00:00:00","2015-07-09T00:00:00","2015-07-10T00:00:00","2015-07-11T00:00:00","2015-07-12T00:00:00","2015-07-13T00:00:00","2015-07-14T00:00:00","2015-07-15T00:00:00","2015-07-16T00:00:00","2015-07-17T00:00:00","2015-07-18T00:00:00","2015-07-19T00:00:00","2015-07-20T00:00:00","2015-07-21T00:00:00","2015-07-23T00:00:00","2015-07-24T00:00:00","2015-07-25T00:00:00","2015-07-26T00:00:00","2015-07-27T00:00:00","2015-07-28T00:00:00","2015-07-29T00:00:00","2015-07-30T00:00:00","2015-07-31T00:00:00","2015-08-01T00:00:00","2015-08-02T00:00:00","2015- ...

# %%
# Distribution of Pollutants in the air quality of Los Angeles
pollutants = ['CO', 'NO2', 'Ozone', 'PM2.5', 'PM10', 'SO2']
pollutant_colors = px.colors.qualitative.Plotly

# Calculate the sum of pollutant concentrations
total_concentrations = combine[pollutants].sum()

# Create a DataFrame for the concentrations
concentration_data = pd.DataFrame({
    "Pollutant": pollutants,
    "Concentration": total_concentrations
})

# Create a donut plot for pollutant concentrations
fig = px.pie(concentration_data, names="Pollutant", values="Concentration",
             title="Pollutant Concentrations in Los Angeles",
             hole=0.4, color_discrete_sequence=pollutant_colors)

# Update layout for the donut plot
fig.update_traces(textinfo="percent+label")
fig.update_layout(legend_title="Pollutant")

# Show the donut plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7a3d5519-ff48-47cb-8083-43add099c6c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a3d5519-ff48-47cb-8083-43add099c6c4")) {                    Plotly.newPlot(                        "7a3d5519-ff48-47cb-8083-43add099c6c4",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"Pollutant=%{label}\u003cbr\u003eConcentration=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["CO","NO2","Ozone","PM2.5","PM10","SO2"],"legendgroup":"","name":"","showlegend":true,"values":[1112.5048951048952,60432.89649544899,100.83265602188922,26448.305540426354,57081.39404761905,3273.4333333333334],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo" ...

# %%
# Correlation Between Pollutants
correlation_matrix = combine[pollutants].corr()
fig = px.imshow(correlation_matrix, x=pollutants, y=pollutants, title="Correlation Between Pollutants")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6572d26e-fa76-4e94-8fda-3b23ccf45c72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6572d26e-fa76-4e94-8fda-3b23ccf45c72")) {                    Plotly.newPlot(                        "6572d26e-fa76-4e94-8fda-3b23ccf45c72",                        [{"coloraxis":"coloraxis","name":"0","x":["CO","NO2","Ozone","PM2.5","PM10","SO2"],"y":["CO","NO2","Ozone","PM2.5","PM10","SO2"],"z":[[1.0,0.8676683065967415,-0.3596422225367219,0.41547670678544424,0.03587880597112212,0.4497229477502262],[0.8676683065967415,1.0,-0.20112074957252737,0.31038325285939017,0.10265837532716579,0.5370422276627937],[-0.3596422225367219,-0.20112074957252737,1.0,0.19786697685412766,0.45798714873057894,0.08813243006030774],[0.41547670678544424,0.31038325285939017,0.19786697685412766,1.0,0.6004325431138191,0.18825847242933014],[0.03587880597112212,0.10265837532716579,0.45798714873057894,0.6004325431138191,1.0,0.14429727746108292],[0.4497229477502262,0.5370422276627937,0.08813243006030774,0.18825847242933014,0.14429727746108292,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"sca ...

# %%
# Correlation Between Pollutants and Number of Hospitalization
parameters = ['CO', 'NO2', 'Ozone', 'PM2.5', 'SO2', 'AQI', 'NUMBER OF HOSPITALIZATIONS']
correlation_matrix = merged_data[parameters].corr()
fig = px.imshow(correlation_matrix, x=parameters, y=parameters, title="Correlation Between Pollutants and No. of Hospitalization")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5c1c9b81-aac9-4aef-aa57-d4f3880dea04" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c1c9b81-aac9-4aef-aa57-d4f3880dea04")) {                    Plotly.newPlot(                        "5c1c9b81-aac9-4aef-aa57-d4f3880dea04",                        [{"coloraxis":"coloraxis","name":"0","x":["CO","NO2","Ozone","PM2.5","SO2","AQI","NUMBER OF HOSPITALIZATIONS"],"y":["CO","NO2","Ozone","PM2.5","SO2","AQI","NUMBER OF HOSPITALIZATIONS"],"z":[[1.0,0.8677387379159808,0.2935729586573326,0.4291052414861132,0.7208891329533867,0.8910823759121601,0.21620703793309043],[0.8677387379159808,1.0,-0.09542925794347472,0.11273844457236566,0.8407209943365589,0.624915737125901,0.3391081177954391],[0.2935729586573326,-0.09542925794347472,1.0,0.7968209939298737,-0.42576487816191283,0.30159418305370733,-0.16846192150099712],[0.4291052414861132,0.11273844457236566,0.7968209939298737,1.0,-0.17168738361415778,0.5303347904184422,-0.044922504121460635],[0.7208891329533867,0.8407209943365589,-0.42576487816191283,-0.17168738361415778,1.0,0.6307614870939344,0.3076931818949538],[0.8910823759121601,0.624915737125901,0.30159418305370733,0.5303347904184422,0.6307614870939344,1.0,0.11632123184259309],[0.21620703793309043,0.3391081177954391,-0.16846192150099712,-0.044922504121460635,0.3076931818949538,0.11632123184259309,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222 ...

# %%
combine['Day_of_Week'] = combine['Date'].dt.day_name()
average_aqi_by_day = combine.groupby('Day_of_Week')['AQI'].mean().reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

# Create a line plot for daily trends in AQI
fig = px.bar(average_aqi_by_day, x=average_aqi_by_day.index, y="AQI",
              title="Average AQI by Day Trends in Los Angeles")
fig.update_xaxes(title="Day of the Week")
fig.update_yaxes(title="Average AQI")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5d6159ca-8f1c-4329-b777-4f1e23804c61" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d6159ca-8f1c-4329-b777-4f1e23804c61")) {                    Plotly.newPlot(                        "5d6159ca-8f1c-4329-b777-4f1e23804c61",                        [{"alignmentgroup":"True","hovertemplate":"Day_of_Week=%{x}\u003cbr\u003eAQI=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],"xaxis":"x","y":[119.96805111821087,123.00319488817891,124.92012779552715,125.95541401273886,125.71884984025559,115.65495207667732,107.98722044728434],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5}," ...

# %%
combine['Year'] = combine['Date'].dt.year
average_aqi_by_year = combine.groupby('Year')['AQI'].mean()

# Create a line plot for daily trends in AQI
fig = px.bar(average_aqi_by_year, x=average_aqi_by_year.index, y="AQI",
              title="Average AQI by Year Trends in Los Angeles")
fig.update_xaxes(title="Year")
fig.update_yaxes(title="Average AQI")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="90fc34db-dc8f-4d9d-bbe8-966aababe384" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90fc34db-dc8f-4d9d-bbe8-966aababe384")) {                    Plotly.newPlot(                        "90fc34db-dc8f-4d9d-bbe8-966aababe384",                        [{"alignmentgroup":"True","hovertemplate":"Year=%{x}\u003cbr\u003eAQI=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[120.0,123.49726775956285,125.61643835616438,121.0958904109589,113.01369863013699,119.53551912568307],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scatter ...

# %%
import calendar
combine['Month'] = combine['Date'].dt.month.apply(lambda x: calendar.month_abbr[x])
average_aqi_by_month = combine.groupby('Month')['AQI'].mean()
# Create a line plot for daily trends in AQI
fig = px.bar(average_aqi_by_month, x=average_aqi_by_month.index, y="AQI",
              title="Average AQI by Month Trends in Los Angeles")
fig.update_xaxes(title="Months")
fig.update_yaxes(title="Average AQI")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="11e4636c-451f-446d-8785-fb4bf6a71285" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11e4636c-451f-446d-8785-fb4bf6a71285")) {                    Plotly.newPlot(                        "11e4636c-451f-446d-8785-fb4bf6a71285",                        [{"alignmentgroup":"True","hovertemplate":"Month=%{x}\u003cbr\u003eAQI=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Apr","Aug","Dec","Feb","Jan","Jul","Jun","Mar","May","Nov","Oct","Sep"],"xaxis":"x","y":[110.27777777777777,120.96774193548387,128.49462365591398,123.23529411764706,121.50537634408602,121.50537634408602,112.5,111.82795698924731,102.68817204301075,130.55555555555554,135.21505376344086,126.94444444444444],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"}," ...

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dense

#Convert 'Date' to datetime and set it as the index
combine['Date'] = pd.to_datetime(combine['Date'])
combine.set_index('Date', inplace=True)

# %%
# Feature Scaling
scaler = MinMaxScaler()
combine['AQI_scaled'] = scaler.fit_transform(combine['AQI'].values.reshape(-1,1))

# %%
# Define sequence length and number of future time steps to predict
sequence_length = 30
#num_future_steps = 3 # Adjust according to needs

# function to create sequences for LSTM
def create_sequences(data, seq_length):
  X = []
  y = []
  for i in range(len(data) - seq_length):
    X.append(data[i:i+seq_length])
    y.append(data[i+seq_length])
  return np.array(X), np.array(y)

# %%
# Create sequences with multiple future time steps
X, y = create_sequences(combine['AQI_scaled'], sequence_length)

# Split the data into training and testing sets
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Reshape data for LSTM input
#X_train = X_train.reshape((X_train.shape[0], sequence_length, len(target_variable)))
#X_test = X_test.reshape((X_test.shape[0], sequence_length, len(target_variable )))

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, activation='relu', input_shape=(sequence_length, 1)))
model.add(Dense(units=1)) # Output layer with units equal to (num_future_steps * num_target_variables)

model.compile(optimizer='adam', loss='mse')
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 44/44 [==============================] - 13s 108ms/step - loss: 0.1031 - val_loss: 0.0219
# Epoch 2/50
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0289 - val_loss: 0.0217
# Epoch 3/50
# 44/44 [==============================] - 2s 49ms/step - loss: 0.0284 - val_loss: 0.0232
# Epoch 4/50
# 44/44 [==============================] - 2s 47ms/step - loss: 0.0280 - val_loss: 0.0217
# Epoch 5/50
# 44/44 [==============================] - 2s 46ms/step - loss: 0.0280 - val_loss: 0.0209
# Epoch 6/50
# 44/44 [==============================] - 2s 48ms/step - loss: 0.0275 - val_loss: 0.0207
# Epoch 7/50
# 44/44 [==============================] - 4s 91ms/step - loss: 0.0271 - val_loss: 0.0216
# Epoch 8/50
# 44/44 [==============================] - 3s 76ms/step - loss: 0.0269 - val_loss: 0.0208
# Epoch 9/50
# 44/44 [==============================] - 2s 46ms/step - loss: 0.0268 - val_loss: 0.0201
# Epoch 10/50
# 44/44 [==============================] - 2s 48ms/step - loss: 0.0262 - val_loss: 0.0250
# Epoch 11/50
# 44/44 [==============================] - 2s 46ms/step - loss: 0.0274 - val_loss: 0.0248
# Epoch 12/50
# 44/44 [==============================] - 2s 48ms/step - loss: 0.0270 - val_loss: 0.0198
# Epoch 13/50
# 44/44 [==============================] - 3s 71ms/step - loss: 0.0264 - val_loss: 0.0198
# Epoch 14/50
# 44/44 [==============================] - 4s 93ms/step - loss: 0.0261 - val_loss: 0.0199
# Epoch 15/50
# 44/44 [==============================] - 2s 52ms/step - loss: 0.0259 - val_loss: 0.0194
# Epoch 16/50
# 44/44 [==============================] - 2s 47ms/step - loss: 0.0265 - val_loss: 0.0197
# Epoch 17/50
# 44/44 [==============================] - 2s 51ms/step - loss: 0.0262 - val_loss: 0.0200
# Epoch 18/50
# 44/44 [==============================] - 2s 46ms/step - loss: 0.0256 - val_loss: 0.0219
# Epoch 19/50
# 44/44 [==============================] - 2s 51ms/step - loss: 0.0263 - val_loss: 0.0196
# Epoch 20/50
# 44/44 [==============================] - 4s 95ms/step - loss: 0.0264 - val_loss: 0.0202
# Epoch 21/50
# 44/44 [==============================] - 3s 67ms/step - loss: 0.0260 - val_loss: 0.0202
# Epoch 22/50
# 44/44 [==============================] - 2s 46ms/step - loss: 0.0258 - val_loss: 0.0194
# Epoch 23/50
# 44/44 [==============================] - 2s 46ms/step - loss: 0.0258 - val_loss: 0.0194
# Epoch 24/50
# 44/44 [==============================] - 2s 46ms/step - loss: 0.0258 - val_loss: 0.0193
# Epoch 25/50
# 44/44 [==============================] - 2s 47ms/step - loss: 0.0257 - val_loss: 0.0201
# Epoch 26/50
# 44/44 [==============================] - 3s 78ms/step - loss: 0.0259 - val_loss: 0.0198
# Epoch 27/50
# 44/44 [==============================] - 4s 90ms/step - loss: 0.0260 - val_loss: 0.0200
# Epoch 28/50
# 44/44 [==============================] - 2s 46ms/step - loss: 0.0256 - val_loss: 0.0216
# Epoch 29/50
# 44/44 [==============================] - 3s 61ms/step - loss: 0.0258 - val_loss: 0.0204
# Epoch 30/50
# 44/44 [==============================] - 2s 53ms/step - loss: 0.0255 - val_loss: 0.0193
# Epoch 31/50
# 44/44 [==============================] - 2s 47ms/step - loss: 0.0258 - val_loss: 0.0201
# Epoch 32/50
# 44/44 [==============================] - 3s 76ms/step - loss: 0.0256 - val_loss: 0.0199
# Epoch 33/50
# 44/44 [==============================] - 4s 94ms/step - loss: 0.0258 - val_loss: 0.0199
# Epoch 34/50
# 44/44 [==============================] - 2s 49ms/step - loss: 0.0258 - val_loss: 0.0200
# Epoch 35/50
# 44/44 [==============================] - 2s 47ms/step - loss: 0.0255 - val_loss: 0.0197
# Epoch 36/50
# 44/44 [==============================] - 2s 50ms/step - loss: 0.0257 - val_loss: 0.0193
# Epoch 37/50
# 44/44 [==============================] - 2s 48ms/step - loss: 0.0260 - val_loss: 0.0192
# Epoch 38/50
# 44/44 [==============================] - 3s 65ms/step - loss: 0.0258 - val_loss: 0.0193
# Epoch 39/50
# 44/44 [==============================] - 4s 95ms/step - loss: 0.0255 - val_loss: 0.0192
# Epoch 40/50
# 44/44 [==============================] - 2s 55ms/step - loss: 0.0257 - val_loss: 0.0199
# Epoch 41/50
# 44/44 [==============================] - 2s 50ms/step - loss: 0.0255 - val_loss: 0.0194
# Epoch 42/50
# 44/44 [==============================] - 2s 49ms/step - loss: 0.0259 - val_loss: 0.0195
# Epoch 43/50
# 44/44 [==============================] - 2s 47ms/step - loss: 0.0255 - val_loss: 0.0193
# Epoch 44/50
# 44/44 [==============================] - 2s 50ms/step - loss: 0.0258 - val_loss: 0.0202
# Epoch 45/50
# 44/44 [==============================] - 4s 96ms/step - loss: 0.0256 - val_loss: 0.0194
# Epoch 46/50
# 44/44 [==============================] - 3s 70ms/step - loss: 0.0254 - val_loss: 0.0196
# Epoch 47/50
# 44/44 [==============================] - 2s 48ms/step - loss: 0.0255 - val_loss: 0.0196
# Epoch 48/50
# 44/44 [==============================] - 2s 48ms/step - loss: 0.0257 - val_loss: 0.0194
# Epoch 49/50
# 44/44 [==============================] - 2s 49ms/step - loss: 0.0257 - val_loss: 0.0197
# Epoch 50/50
# 44/44 [==============================] - 2s 45ms/step - loss: 0.0255 - val_loss: 0.0195

# %%
# make predictions
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 14/14 [==============================] - 0s 6ms/step

# %%
# evaluate the performance of the model
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(combine['AQI'][train_size+sequence_length:], predictions)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 589.3050008768877

# %%
# Visualize results
plt.figure(figsize=(12,6))
plt.plot(combine.index[train_size+sequence_length:], combine['AQI'][train_size+sequence_length:], label='Actual')
plt.plot(combine.index[train_size+sequence_length:], predictions, label='Predicted')
plt.legend()

# %%
# Pollutant CO
combine['CO_scaled'] = scaler.fit_transform(combine['CO'].values.reshape(-1,1))

# %%
#Create sequences with multiple future time steps
X_CO, y_CO = create_sequences(combine['CO_scaled'], sequence_length)

# Split the data into training and testing sets
train_size = int(len(X) * 0.8)
X_CO_train, X_CO_test = X_CO[:train_size], X_CO[train_size:]
y_CO_train, y_CO_test = y_CO[:train_size], y_CO[train_size:]

# %%
# Build the LSTM model
model2 = Sequential()
model2.add(LSTM(units=50, activation='relu', input_shape=(sequence_length, 1)))
model2.add(Dense(units=1)) # Output layer with units equal to (num_future_steps * num_target_variables)

model2.compile(optimizer='adam', loss='mse')
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
X_CO_train = X_CO_train.reshape((X_CO_train.shape[0], X_CO_train.shape[1], 1))
# Train the model
model2.fit(X_CO_train, y_CO_train, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/20
# 44/44 [==============================] - 4s 52ms/step - loss: 0.0281 - val_loss: 0.0120
# Epoch 2/20
# 44/44 [==============================] - 4s 91ms/step - loss: 0.0138 - val_loss: 0.0110
# Epoch 3/20
# 44/44 [==============================] - 3s 75ms/step - loss: 0.0133 - val_loss: 0.0108
# Epoch 4/20
# 44/44 [==============================] - 2s 48ms/step - loss: 0.0129 - val_loss: 0.0106
# Epoch 5/20
# 44/44 [==============================] - 2s 47ms/step - loss: 0.0128 - val_loss: 0.0104
# Epoch 6/20
# 44/44 [==============================] - 2s 49ms/step - loss: 0.0125 - val_loss: 0.0102
# Epoch 7/20
# 44/44 [==============================] - 2s 49ms/step - loss: 0.0123 - val_loss: 0.0101
# Epoch 8/20
# 44/44 [==============================] - 3s 76ms/step - loss: 0.0121 - val_loss: 0.0100
# Epoch 9/20
# 44/44 [==============================] - 4s 94ms/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 10/20
# 44/44 [==============================] - 2s 46ms/step - loss: 0.0117 - val_loss: 0.0096
# Epoch 11/20
# 44/44 [==============================] - 2s 47ms/step - loss: 0.0115 - val_loss: 0.0094
# Epoch 12/20
# 44/44 [==============================] - 2s 46ms/step - loss: 0.0114 - val_loss: 0.0093
# Epoch 13/20
# 44/44 [==============================] - 2s 46ms/step - loss: 0.0112 - val_loss: 0.0089
# Epoch 14/20
# 44/44 [==============================] - 2s 51ms/step - loss: 0.0109 - val_loss: 0.0087
# Epoch 15/20
# 44/44 [==============================] - 4s 93ms/step - loss: 0.0104 - val_loss: 0.0087
# Epoch 16/20
# 44/44 [==============================] - 3s 68ms/step - loss: 0.0101 - val_loss: 0.0082
# Epoch 17/20
# 44/44 [==============================] - 2s 48ms/step - loss: 0.0098 - val_loss: 0.0081
# Epoch 18/20
# 44/44 [==============================] - 2s 46ms/step - loss: 0.0097 - val_loss: 0.0079
# Epoch 19/20
# 44/44 [==============================] - 2s 46ms/step - loss: 0.0095 - val_loss: 0.0077
# Epoch 20/20
# 44/44 [==============================] - 2s 47ms/step - loss: 0.0093 - val_loss: 0.0077

# %%
# make predictions
X_CO_test = X_CO_test.reshape((X_CO_test.shape[0], X_CO_test.shape[1], 1))
predictionsCO = model2.predict(X_CO_test)
predictionsCO = scaler.inverse_transform(predictionsCO)
# Out:
# 14/14 [==============================] - 1s 18ms/step

# %%
# evaluate the performance of the model
mseCO = mean_squared_error(combine['CO'][train_size+sequence_length:], predictionsCO)
print(f'Mean Squared Error: {mseCO}')
# Out:
# Mean Squared Error: 0.01882774857735199

# %%
# Visualize results
plt.figure(figsize=(12,6))
plt.plot(combine.index[train_size+sequence_length:], combine['CO'][train_size+sequence_length:], label='Actual')
plt.plot(combine.index[train_size+sequence_length:], predictionsCO, label='Predicted')
plt.legend()

# %%
model2.save('Los-Angeles-CO.keras')

# %%
model.save('Los-Angeles-AQI.keras')

# %%
# Pollutant PM2.5
combine['PM2.5_scaled'] = scaler.fit_transform(combine['PM2.5'].values.reshape(-1,1))

# %%
#Create sequences with multiple future time steps
X_PM, y_PM = create_sequences(combine['PM2.5_scaled'], sequence_length)

# Split the data into training and testing sets
train_size = int(len(X) * 0.8)
X_PM_train, X_PM_test = X_PM[:train_size], X_PM[train_size:]
y_PM_train, y_PM_test = y_PM[:train_size], y_PM[train_size:]

# %%
# Build the LSTM model
model3 = Sequential()
model3.add(LSTM(units=50, activation='relu', input_shape=(sequence_length, 1)))
model3.add(Dense(units=1)) # Output layer with units equal to (num_future_steps * num_target_variables)

model3.compile(optimizer='adam', loss='mse')
# Out:
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
X_PM_train = X_PM_train.reshape((X_PM_train.shape[0], X_PM_train.shape[1], 1))
# Train the model
model3.fit(X_PM_train, y_PM_train, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/20
# 44/44 [==============================] - 4s 50ms/step - loss: 0.0114 - val_loss: 0.0043
# Epoch 2/20
# 44/44 [==============================] - 3s 77ms/step - loss: 0.0059 - val_loss: 0.0044
# Epoch 3/20
# 44/44 [==============================] - 4s 88ms/step - loss: 0.0056 - val_loss: 0.0042
# Epoch 4/20
# 44/44 [==============================] - 2s 49ms/step - loss: 0.0054 - val_loss: 0.0040
# Epoch 5/20
# 44/44 [==============================] - 2s 46ms/step - loss: 0.0052 - val_loss: 0.0043
# Epoch 6/20
# 44/44 [==============================] - 2s 45ms/step - loss: 0.0051 - val_loss: 0.0035
# Epoch 7/20
# 44/44 [==============================] - 2s 47ms/step - loss: 0.0050 - val_loss: 0.0036
# Epoch 8/20
# 44/44 [==============================] - 2s 52ms/step - loss: 0.0046 - val_loss: 0.0034
# Epoch 9/20
# 44/44 [==============================] - 4s 92ms/step - loss: 0.0045 - val_loss: 0.0033
# Epoch 10/20
# 44/44 [==============================] - 3s 65ms/step - loss: 0.0044 - val_loss: 0.0031
# Epoch 11/20
# 44/44 [==============================] - 2s 46ms/step - loss: 0.0042 - val_loss: 0.0033
# Epoch 12/20
# 44/44 [==============================] - 2s 56ms/step - loss: 0.0046 - val_loss: 0.0031
# Epoch 13/20
# 44/44 [==============================] - 2s 45ms/step - loss: 0.0041 - val_loss: 0.0029
# Epoch 14/20
# 44/44 [==============================] - 2s 47ms/step - loss: 0.0038 - val_loss: 0.0030
# Epoch 15/20
# 44/44 [==============================] - 4s 91ms/step - loss: 0.0038 - val_loss: 0.0029
# Epoch 16/20
# 44/44 [==============================] - 3s 73ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 17/20
# 44/44 [==============================] - 2s 46ms/step - loss: 0.0036 - val_loss: 0.0027
# Epoch 18/20
# 44/44 [==============================] - 2s 45ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 19/20
# 44/44 [==============================] - 2s 47ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 20/20
# 44/44 [==============================] - 2s 47ms/step - loss: 0.0033 - val_loss: 0.0027

# %%
# make predictions
X_PM_test = X_PM_test.reshape((X_PM_test.shape[0], X_PM_test.shape[1], 1))
predictionsPM = model3.predict(X_PM_test)
predictionsPM = scaler.inverse_transform(predictionsPM)
# Out:
# 14/14 [==============================] - 1s 18ms/step

# %%
# evaluate the performance of the model
msePM = mean_squared_error(combine['PM2.5'][train_size+sequence_length:], predictionsPM)
print(f'Mean Squared Error: {msePM}')
# Out:
# Mean Squared Error: 24.105973042953508

# %%
# Visualize results
plt.figure(figsize=(12,6))
plt.plot(combine.index[train_size+sequence_length:], combine['PM2.5'][train_size+sequence_length:], label='Actual')
plt.plot(combine.index[train_size+sequence_length:], predictionsPM, label='Predicted')
plt.legend()

# %%
model3.save('Los-Angeles-PM2.5.keras')
